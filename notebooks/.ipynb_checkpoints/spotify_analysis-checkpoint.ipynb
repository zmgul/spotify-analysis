# %% [markdown]
# # 🎧 Understanding Spotify Listeners: Music Preferences by Age and Gender
#
# This project analyzes music genre preferences across different age groups and genders using a synthetic dataset.
# The dataset includes age group, gender and preferred music genre of Spotify users.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("../data/spotify_listener_segments.csv")
df.head(10)
# Out:
#   age_group  gender preferred_genre
# 0       55+  Female            Rock
# 1     13-17  Female             EDM
# 2     13-17  Female             Pop
# 3       55+  Female           Indie
# 4     25-34    Male            Jazz
# 5     18-24  Female            Jazz
# 6     18-24  Female           Indie
# 7     18-24  Female           K-pop
# 8       55+    Male       Classical
# 9     13-17  Female            Jazz

# %%
# Music genre preferences by age group
plt.figure(figsize=(10, 6))
age_groups = ["13-17", "18-24", "25-34", "35-44", "45-54", "55+"]
sns.countplot(data=df, x="age_group", hue="preferred_genre", order=age_groups)

plt.title("Music Genre Preferences by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.legend(title="Genre", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Music genre preferences by gender
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="gender", hue="preferred_genre", order=["Female", "Male"])

plt.title("Music Genre Preferences by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Genre", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧠 Conclusions and Insights
#
# The analysis reveals notable differences in music genre preferences across both age groups and genders:
#
# - **Age-Based Preferences**:
#   - Younger users (ages 13–24) show a strong inclination toward high-energy and trend-driven genres such as **K-pop**, **EDM** and **Pop** which often dominate platforms like TikTok and Instagram Reels.
#   - Adults aged 25–34 exhibit more diverse preferences, balancing upbeat genres like **Hip-Hop** and **Indie** with more introspective styles like **Jazz**.
#   - Users aged 35 and above show a clear preference for more classic and mellow genres such as **Rock**, **Jazz** and **Classical** suggesting stronger ties to nostalgia and long-form listening.
#
# - **Gender-Based Preferences**:
#   - **Female users** are more likely to favor emotionally expressive and rhythm-driven genres such as **Pop**, **K-pop** and **EDM**.
#   - **Male users**, on the other hand, lean towards genres like **Rock**, **Jazz** and **Hip-Hop** which are often associated with traditional instrumentation and lyrical complexity.
#
# - These trends suggest that **target audience characteristics play a significant role in shaping music listening behavior**. These insights can be valuable for:
#   - Developing personalized music recommendation systems
#   - Designing targeted marketing strategies for streaming platforms
#   - Helping artists tailor their content for specific audience segments
#
# In an era where personalization drives user engagement, this analysis highlights the power of target audience insights in shaping the future of music discovery and digital experiences.
# By leveraging basic user attributes such as age and gender, content recommendations can be made more strategic while the overall user experience becomes more meaningful and sustainable.
# This lays the groundwork for more human-centered recommendation systems.
